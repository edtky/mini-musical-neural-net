# %%
import os, glob, sys

# %%
os.chdir('/Users/edwardtiong/Desktop/djgan/mini-neural-waltz')
# Out:
# '/Users/edwardtiong/Desktop/djgan/mini-neural-waltz'

# %%
import notewise_decoder as nd

# %%
folder = './training_output/run02_2018-11-14/samples/*txt'

# %%
for file in glob.glob(folder):
    filename = file[-53:]
    nd.main(filename)
# Out:
# Done! Decoded midi file saved to '/output-midi-files/notewise/custom/'
# Done! Decoded midi file saved to '/output-midi-files/notewise/custom/'
# Done! Decoded midi file saved to '/output-midi-files/notewise/custom/'
# Done! Decoded midi file saved to '/output-midi-files/notewise/custom/'
# Done! Decoded midi file saved to '/output-midi-files/notewise/custom/'
# Done! Decoded midi file saved to '/output-midi-files/notewise/custom/'
# Done! Decoded midi file saved to '/output-midi-files/notewise/custom/'
# Done! Decoded midi file saved to '/output-midi-files/notewise/custom/'
# Done! Decoded midi file saved to '/output-midi-files/notewise/custom/'
# Done! Decoded midi file saved to '/output-midi-files/notewise/custom/'
# Done! Decoded midi file saved to '/output-midi-files/notewise/custom/'
# Done! Decoded midi file saved to '/output-midi-files/notewise/custom/'
# Done! Decoded midi file saved to '/output-midi-files/notewise/custom/'
# ...

# %%
nd.main(filename)
# Out:
# Done! Decoded midi file saved to '/output-midi-files/notewise/custom/'
