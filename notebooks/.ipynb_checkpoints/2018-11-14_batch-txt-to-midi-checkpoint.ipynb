# %%
import os, glob
import notewise_decoder as nd

# %%
folder = '../training_output/run01_2018-11-14/samples/*txt'

# %%
for file in glob.glob(folder):
    filename = file[-53:]
    nd.main(filename)
# Out:
# Done! Decoded midi file saved to '/output-midi-files/notewise/custom/'
# Done! Decoded midi file saved to '/output-midi-files/notewise/custom/'
# Done! Decoded midi file saved to '/output-midi-files/notewise/custom/'
# Done! Decoded midi file saved to '/output-midi-files/notewise/custom/'
# Done! Decoded midi file saved to '/output-midi-files/notewise/custom/'
# Done! Decoded midi file saved to '/output-midi-files/notewise/custom/'
# Done! Decoded midi file saved to '/output-midi-files/notewise/custom/'
# Done! Decoded midi file saved to '/output-midi-files/notewise/custom/'
# Done! Decoded midi file saved to '/output-midi-files/notewise/custom/'
# Done! Decoded midi file saved to '/output-midi-files/notewise/custom/'
# Done! Decoded midi file saved to '/output-midi-files/notewise/custom/'
# Done! Decoded midi file saved to '/output-midi-files/notewise/custom/'
# Done! Decoded midi file saved to '/output-midi-files/notewise/custom/'
# ...

# %%
file = '../training_output/run01_2018-11-14/samples/result_epoch070_batch500.txt'

# %%
filename = file[-53:]
filename
# Out:
# 'run01_2018-11-14/samples/result_epoch109_batch600.txt'

# %%
nd.main(filename)
# Out:
# Done! Decoded midi file saved to '/output-midi-files/notewise/custom/'
